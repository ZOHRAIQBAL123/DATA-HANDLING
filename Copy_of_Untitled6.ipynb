# %% [markdown]
# <a href="https://colab.research.google.com/github/ZOHRAIQBAL123/DATA-HANDLING/blob/main/Copy_of_Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pllt

cars_data=pd.read_csv("/ToyotaCorolla.csv",index_col=0,na_values=['??','????'])

cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 13500 to 6950
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        1436 non-null   int64
#  1   KM         1436 non-null   int64
#  2   FuelType   1436 non-null   object
#  3   HP         1436 non-null   int64
#  4   MetColor   1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   CC         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Weight     1436 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 112.2+ KB

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data
# Out:
#        Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight
# Price
# 13500   23  46986   Diesel   90         1          0  2000      3    1165
# 13750   23  72937   Diesel   90         1          0  2000      3    1165
# 13950   24  41711   Diesel   90         1          0  2000      3    1165
# 14950   26  48000   Diesel   90         0          0  2000      3    1165
# 13750   30  38500   Diesel   90         0          0  2000      3    1170
# ...    ...    ...      ...  ...       ...        ...   ...    ...     ...
# 7500    69  20544   Petrol   86         1          0  1300      3    1025
# 10845   72  19000   Petrol   86         0          0  1300      3    1015
# 8500    71  17016   Petrol   86         0          0  1300      3    1015
# 7250    70  16916   Petrol   86         1          0  1300      3    1015
# 6950    76      1   Petrol  110         0          0  1600      5    1114
#
# [1436 rows x 9 columns]

# %%
plt.scanner(cars_data['Age'],cars_data['Price'],c='red')
plt.title('Scatter plot of price vs age')
plt.xlabel('age(month)')
plt.ylabel('price(Euros)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7357d6fb5e0e> in <cell line: 1>()
# ----> 1 plt.scanner(cars_data['Age'],cars_data['Price'],c='red')
#       2 plt.title('Scatter plot of price vs age')
#       3 plt.xlabel('age(month)')
#       4 plt.ylabel('price(Euros)')
#       5 plt.show()
#
# NameError: name 'plt' is not defined
